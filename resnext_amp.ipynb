# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary
from amp import AMP
import matplotlib.pyplot as plt


import os
import argparse

# %%
class Block(nn.Module):
    '''Grouped convolution block.'''
    expansion = 2

    def __init__(self, in_planes, cardinality=32, bottleneck_width=4, stride=1):
        super(Block, self).__init__()
        group_width = cardinality * bottleneck_width
        self.conv1 = nn.Conv2d(in_planes, group_width, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(group_width)
        self.conv2 = nn.Conv2d(group_width, group_width, kernel_size=3, stride=stride, padding=1, groups=cardinality, bias=False)
        self.bn2 = nn.BatchNorm2d(group_width)
        self.conv3 = nn.Conv2d(group_width, self.expansion*group_width, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*group_width)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*group_width:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*group_width, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*group_width)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNeXt(nn.Module):
    def __init__(self, num_blocks, cardinality, bottleneck_width, num_classes=10):
        super(ResNeXt, self).__init__()
        self.cardinality = cardinality
        self.bottleneck_width = bottleneck_width
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(num_blocks[0], 1)
        self.layer2 = self._make_layer(num_blocks[1], 2)
        self.layer3 = self._make_layer(num_blocks[2], 2)
        # self.layer4 = self._make_layer(num_blocks[3], 2)
        self.linear = nn.Linear(cardinality*bottleneck_width*8, num_classes)

    def _make_layer(self, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(Block(self.in_planes, self.cardinality, self.bottleneck_width, stride))
            self.in_planes = Block.expansion * self.cardinality * self.bottleneck_width
        # Increase bottleneck_width by 2 after each stage.
        self.bottleneck_width *= 2
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        # out = self.layer4(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def MyResNeXt():
    return ResNeXt(num_blocks=[3,3,3], cardinality=32, bottleneck_width=4)

# %%
model = MyResNeXt()
sum = 0
for p in model.parameters():
    sum += p.numel()
print(sum)
#summary(model)
# Out:
# 4761770

# %%
learning_rate = 0.001
batch_size = 64
epochs = 100
weight_decay = 0.0001
#best_acc = 0


transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Load CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

# Define your data loader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Define your optimizer and loss function
device = 'cuda' if torch.cuda.is_available else 'cpu'
print(device)
model.to(device)
optimizer = AMP(model.parameters(), lr=0.1, epsilon=0.5, momentum=0.9)
#optimizer.to(device)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

#criterion.to(device)
# Out:
# cuda

# %%
train_losses = []
train_accs = []

def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    train_loss = 0.0
    total = 0
    correct = 0
    

    def closure(data, target):
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        return output, loss


    for batch_idx, (data, target) in enumerate(train_loader):
        output, loss = optimizer.step(lambda: closure(data, target))

        data, target = data.to(device), target.to(device)

        # Calculate training loss and accuracy
        train_loss += loss.item()
        _, predicted = output.max(1)
        total += target.size(0)
        correct += predicted.eq(target).sum().item()

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    train_acc = 100. * correct / total
    train_accs.append(train_acc)

    print('Train Loss: %.3f | Acc: %.3f%% (%d/%d)'
          % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))

# %%
best_acc = 0.0
test_losses = []
test_accs = []

def test(model, device, test_loader, criterion):
    global best_acc
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item() * data.size(0)
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    test_acc = correct / len(test_loader.dataset)
    test_accs.append(test_acc)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
        # Save checkpoint.
    acc = 100.*correct/len(test_loader.dataset)
    if acc > best_acc:
        print('Saving..')
        state = {
            'model': model.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt.pth')
        best_acc = acc

# %%
# Load checkpoint.
checkpoint = torch.load('./checkpoint/ckpt.pth')

# Load model state dict from checkpoint.
model.load_state_dict(checkpoint['model'])

# Load other checkpoint variables such as accuracy and epoch.
acc = checkpoint['acc']
epoch = checkpoint['epoch']


for epoch in range(epochs):
    train(model, device, train_loader, optimizer, criterion, epoch)
    test(model, device, test_loader, criterion)
    scheduler.step()
    
# Plot the loss and accuracy graphs for the train and test data
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title('Training Loss')
axs[0, 1].plot(train_accs)
axs[0, 1].set_title('Training Accuracy')
axs[1, 0].plot(test_losses)
axs[1, 0].set_title('Test Loss')
axs[1, 1].plot(test_accs)
axs[1, 1].set_title('Test Accuracy')
plt.show()
# Out:
# Train Loss: 0.000 | Acc: 89.300% (44650/50000)
# Test set: Average loss: 0.4034, Accuracy: 8617/10000 (86%)
#
# Train Loss: 0.000 | Acc: 89.606% (44803/50000)
# Test set: Average loss: 0.3873, Accuracy: 8676/10000 (87%)
#
# Saving..
# Train Loss: 0.000 | Acc: 89.668% (44834/50000)
# Test set: Average loss: 0.4161, Accuracy: 8568/10000 (86%)
#
# Train Loss: 0.000 | Acc: 90.192% (45096/50000)
# Test set: Average loss: 0.4043, Accuracy: 8652/10000 (87%)
#
# Train Loss: 0.000 | Acc: 90.382% (45191/50000)
# Test set: Average loss: 0.3766, Accuracy: 8739/10000 (87%)
#
# Saving..
# Train Loss: 0.000 | Acc: 90.662% (45331/50000)
# Test set: Average loss: 0.3678, Accuracy: 8755/10000 (88%)
#
# Saving..
# Train Loss: 0.000 | Acc: 91.064% (45532/50000)
# Test set: Average loss: 0.3601, Accuracy: 8776/10000 (88%)
#
# Saving..
# Train Loss: 0.000 | Acc: 91.246% (45623/50000)
# Test set: Average loss: 0.3493, Accuracy: 8809/10000 (88%)
#
# Saving..
# Train Loss: 0.000 | Acc: 91.564% (45782/50000)
# Test set: Average loss: 0.3439, Accuracy: 8857/10000 (89%)
#
# Saving..
# Train Loss: 0.000 | Acc: 91.612% (45806/50000)
# Test set: Average loss: 0.3574, Accuracy: 8768/10000 (88%)
#
# Train Loss: 0.000 | Acc: 91.900% (45950/50000)
# Test set: Average loss: 0.3458, Accuracy: 8807/10000 (88%)
#
# Train Loss: 0.000 | Acc: 92.092% (46046/50000)
# Test set: Average loss: 0.3516, Accuracy: 8823/10000 (88%)
#
# Train Loss: 0.000 | Acc: 92.392% (46196/50000)
# Test set: Average loss: 0.3341, Accuracy: 8866/10000 (89%)
#
# Saving..
# Train Loss: 0.000 | Acc: 92.718% (46359/50000)
# Test set: Average loss: 0.3464, Accuracy: 8828/10000 (88%)
#
# Train Loss: 0.000 | Acc: 92.748% (46374/50000)
# Test set: Average loss: 0.3317, Accuracy: 8903/10000 (89%)
#
# Saving..
# Train Loss: 0.000 | Acc: 93.012% (46506/50000)
# Test set: Average loss: 0.3344, Accuracy: 8866/10000 (89%)
#
# Train Loss: 0.000 | Acc: 93.106% (46553/50000)
# Test set: Average loss: 0.3267, Accuracy: 8901/10000 (89%)
#
# Train Loss: 0.000 | Acc: 93.346% (46673/50000)
# Test set: Average loss: 0.3237, Accuracy: 8918/10000 (89%)
#
# Saving..
# Train Loss: 0.000 | Acc: 93.668% (46834/50000)
# Test set: Average loss: 0.3239, Accuracy: 8893/10000 (89%)
#
# Train Loss: 0.000 | Acc: 93.852% (46926/50000)
# Test set: Average loss: 0.3127, Accuracy: 8959/10000 (90%)
#
# Saving..
# Train Loss: 0.000 | Acc: 94.044% (47022/50000)
# Test set: Average loss: 0.3180, Accuracy: 8927/10000 (89%)
#
# Train Loss: 0.000 | Acc: 94.246% (47123/50000)
# Test set: Average loss: 0.3176, Accuracy: 8945/10000 (89%)
#
# Train Loss: 0.000 | Acc: 94.480% (47240/50000)
# Test set: Average loss: 0.3079, Accuracy: 8970/10000 (90%)
#
# Saving..
# Train Loss: 0.000 | Acc: 94.458% (47229/50000)
# Test set: Average loss: 0.3072, Accuracy: 8983/10000 (90%)
#
# Saving..
# Train Loss: 0.000 | Acc: 94.820% (47410/50000)
# Test set: Average loss: 0.3167, Accuracy: 8948/10000 (89%)
#
# Train Loss: 0.000 | Acc: 94.798% (47399/50000)
# Test set: Average loss: 0.3076, Accuracy: 8956/10000 (90%)
#
# Train Loss: 0.000 | Acc: 95.056% (47528/50000)
# Test set: Average loss: 0.3020, Accuracy: 8977/10000 (90%)
#
# Train Loss: 0.000 | Acc: 95.280% (47640/50000)
# Test set: Average loss: 0.2972, Accuracy: 9021/10000 (90%)
#
# Saving..
# Train Loss: 0.000 | Acc: 95.440% (47720/50000)
# Test set: Average loss: 0.3036, Accuracy: 8978/10000 (90%)
#
# Train Loss: 0.000 | Acc: 95.596% (47798/50000)
# Test set: Average loss: 0.3111, Accuracy: 8947/10000 (89%)
#
# Train Loss: 0.000 | Acc: 95.714% (47857/50000)
# Test set: Average loss: 0.2925, Accuracy: 9032/10000 (90%)
#
# Saving..
# Train Loss: 0.000 | Acc: 95.740% (47870/50000)
# Test set: Average loss: 0.2896, Accuracy: 9006/10000 (90%)
#
# Train Loss: 0.000 | Acc: 95.932% (47966/50000)
# Test set: Average loss: 0.2931, Accuracy: 8996/10000 (90%)
#
# Train Loss: 0.000 | Acc: 96.004% (48002/50000)
# Test set: Average loss: 0.2900, Accuracy: 9031/10000 (90%)
#
# Train Loss: 0.000 | Acc: 96.224% (48112/50000)
# Test set: Average loss: 0.2938, Accuracy: 9009/10000 (90%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 13
#       9 epoch = checkpoint['epoch']
#      12 for epoch in range(epochs):
# ---> 13     train(model, device, train_loader, optimizer, criterion, epoch)
#      14     test(model, device, test_loader, criterion)
#      15     scheduler.step()
#
# Cell In[6], line 22, in train(model, device, train_loader, optimizer, criterion, epoch)
#      18     return output, loss
#      21 for batch_idx, (data, target) in enumerate(train_loader):
# ---> 22     output, loss = optimizer.step(lambda: closure(data, target))
#      24     data, target = data.to(device), target.to(device)
#      26     # Calculate training loss and accuracy
#
# File /ext3/miniconda3/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:69, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      67 instance._step_count += 1
#      68 wrapped = func.__get__(instance, cls)
# ---> 69 return wrapped(*args, **kwargs)
#
# File /ext3/miniconda3/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File /ext3/miniconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/scratch/amp.py:59, in AMP.step(self, closure)
#      57 dev = self.state[p]['dev'] + group['inner_lr'] * p.grad
#      58 clip_coef = group['epsilon'] / (dev.norm() + 1e-12)
# ---> 59 dev = clip_coef * dev if clip_coef < 1 else dev
#      60 #p = p.to(device)  # add this line
#      61 p.sub_(self.state[p]['dev']).add_(dev) # update "theta" with "theta+delta"
#
# KeyboardInterrupt:

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title('Training Loss')
axs[0, 1].plot(train_accs)
axs[0, 1].set_title('Training Accuracy')
axs[1, 0].plot(test_losses)
axs[1, 0].set_title('Test Loss')
axs[1, 1].plot(test_accs)
axs[1, 1].set_title('Test Accuracy')
plt.show()

# %%
fig.savefig('loss_accuracy_plot.png')
